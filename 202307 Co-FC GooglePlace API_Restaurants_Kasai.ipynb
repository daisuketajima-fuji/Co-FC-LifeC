# %%
pip install -U googlemaps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
import pprint #list型やDict型を見やすくprintするライブラリ

# %%
# ここでGoogle Maps APIキーを設定します
key = 'AIzaSyB_VPV6jo29eM3pJJ_gCJrStr9ciSFKeGI'
# Google Maps APIを初期化します
client = googlemaps.Client(key)

# %%
# 位置情報を検索
geocode_result = client.geocode('東京都江戸川区葛西5丁目')
# 軽度・緯度の情報のみ取り出す
loc = geocode_result[0]['geometry']['location']

# %%
#半径200m以内のレストランの情報を取得
restaurant_result = client.places_nearby(location=loc, radius=500, type = 'restaurant')

# %%
pprint.pprint(restaurant_result)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aaw_FcKv6q-3_vlJTM17ar3Vr6U-GdpZq_FFPj1kMFDsyF3enCIcXvxo-prz5gIRgVfEYbs6lfBNz5RXiUZyhU8ps-G-r02Uh2ULekSe-0MDF9NvKhONCkxGqwnn7Cslqw6Z-b33FWW3iiv9ieqBkh08RHwag9zxS0MA-KCsbaQiptktoPoiUjIf50FYghUZ46M6lTlaUFqFEp217XOaLLPfnPRhoTlGh8PFM5MytMX6qg0U6t31gvKDAgL1loy94-VnJfEw9b5oCXBdbgroMCZrOPJJpxFc_DA7saYVozDu-Dw80updO0oeqUR2-4pRfftnRNURjyaYupLukk9h_rEoqJJCKXR56ozWTdK84_9DSvckGAHXhtvMAzI72vezcy3-dYi0MbGgWCDzknhEDM6eY2t4nYT7oDw8b5Sfw7uEkva2EPWHNrYOTLlvJpe8',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6704906, 'lng': 139.8663481},
#                            'viewport': {'northeast': {'lat': 35.67179558029149,
#                                                       'lng': 139.8676758802915},
#                                         'southwest': {'lat': 35.6690976197085,
#                                                       'lng': 139.8649779197085}}},
# ...

# %%
# ここから地図を表示する方法は以下のようになります (googlemapsの使用例)
import folium

# %%
# 地図を初期化
map_center = [loc['lat'], loc['lng']]
map_restaurants = folium.Map(location=map_center, zoom_start=17)

# %%
# レストランの位置を地図に追加
for restaurant in restaurant_result['results']:
    lat = restaurant['geometry']['location']['lat']
    lng = restaurant['geometry']['location']['lng']
    name = restaurant['name']
    folium.Marker([lat, lng], popup=name).add_to(map_restaurants)

# %%
# 地図を表示
map_restaurants.save('restaurants_map_kasai5chome.html')  # HTMLファイルに保存
